# %%
import pandas as pd
import numpy as np
import string
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk import pos_tag
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
with open('TrainData.txt') as f:
    lines = f.readlines()

# %%
questions = []
answers = []

# %%
for l in lines:
    as_list = l.split("\t")
    questions.append(as_list[1].replace("\n",""))
    answers.append(as_list[0])

# %%
questions = questions[1:]

# %%
questions[1:5]
# Out:
# ["that one. the one that's all black.",
#  "i got it from macy's.",
#  'when does it start?',
#  "what's the matter with green eyes?"]

# %%
answers = answers[1:]

# %%
df = pd.DataFrame({'Questions':questions,'Answers':answers})
df.head()
# Out:
#                              Questions  \
# 0       The weather is great isn't it?
# 1  that one. the one that's all black.
# 2                i got it from macy's.
# 3                  when does it start?
# 4   what's the matter with green eyes?
#
#                                       Answers
# 0       Yes. It's absolutely beautiful today.
# 1                  yes, i like that one, too.
# 2                           it's really nice.
# 3                                at 8:00 p.m.
# 4  nothing, except my favorite color is blue.

# %%
df.shape
# Out:
# (5495, 2)

# %%
all_data = df.drop_duplicates(subset='Questions')
all_data.head(10)
# Out:
#                                            Questions  \
# 0                     The weather is great isn't it?
# 1                that one. the one that's all black.
# 2                              i got it from macy's.
# 3                                when does it start?
# 4                 what's the matter with green eyes?
# 5                          have you ever read a book
# 6                             what is bioinformatics
# 7                                   Can I try it on?
# 8  Which account are you making this withdrawal f...
# 9                                  that's the truth.
#
#                                              Answers
# 0              Yes. It's absolutely beautiful today.
# 1                         yes, i like that one, too.
# 2                                  it's really nice.
# 3                                       at 8:00 p.m.
# 4         nothing, except my favorite color is blue.
# 5   I have read just about everything in Project ...
# 6   a fancy name for applied computer science in ...
# 7           Sure, the changing rooms are over there.
# 8          I want it taken from my checking account.
# 9            and you get to play with a lot of dogs.

# %%
all_data.shape
# Out:
# (4875, 2)

# %%
all_data = all_data.dropna()
all_data.shape
# Out:
# (4875, 2)

# %%
stopwords_list = stopwords.words('english')

lemmatizer = WordNetLemmatizer()

def my_tokenizer(doc):
    words = word_tokenize(doc)
    
    pos_tags = pos_tag(words)
    
    non_stopwords = [w for w in pos_tags if not w[0].lower() in stopwords_list]
    
    non_punctuation = [w for w in non_stopwords if not w[0] in string.punctuation]
    
    lemmas = []
    for w in non_punctuation:
        if w[1].startswith('J'):
            pos = wordnet.ADJ
        elif w[1].startswith('V'):
            pos = wordnet.VERB
        elif w[1].startswith('N'):
            pos = wordnet.NOUN
        elif w[1].startswith('R'):
            pos = wordnet.ADV
        else:
            pos = wordnet.NOUN
        
        lemmas.append(lemmatizer.lemmatize(w[0], pos))

    return lemmas

# %%
tfidf_vectorizer = TfidfVectorizer(tokenizer=my_tokenizer)
tfidf_matrix = tfidf_vectorizer.fit_transform(tuple(all_data['Questions']))
print(tfidf_matrix.shape)
# Out:
# (4875, 2334)

# %%
def ask_question(question):
    query_vect = tfidf_vectorizer.transform([question])
    similarity = cosine_similarity(query_vect, tfidf_matrix)
    max_similarity = np.argmax(similarity, axis=None)
    
    print('Your question:', question)
    print('Closest question found:', all_data.iloc[max_similarity]['Questions'])
    print('Similarity: {:.2%}'.format(similarity[0, max_similarity]))
    print('Answer:', all_data.iloc[max_similarity]['Answers'])

# %%
def ask_question_modified(question):
    query_vect = tfidf_vectorizer.transform([question])
    similarity = cosine_similarity(query_vect, tfidf_matrix)
    max_similarity = np.argmax(similarity, axis=None)
    return all_data.iloc[max_similarity]['Answers']

# %%
ask_question("i got it from macy's.")
# Out:
# Your question: i got it from macy's.
# Closest question found: i got it from macy's.
# Similarity: 100.00%
# Answer: it's really nice.

# %%
ask_question_modified("i got it from macy's.")
# Out:
# "it's really nice."

# %%
test_df = pd.read_csv('TestData.csv')
test_df.head()
# Out:
#    I.D.                                           Question
# 0  QN_1             i'll give you a speech like that, too.
# 1  QN_2                   i know, you're absolutely right.
# 2  QN_3                                        i liked it.
# 3  QN_4              the baby was eight pounds six ounces.
# 4  QN_5  I was sold a wireless service unavailable in m...

# %%
result = []
for i in test_df['Question']:
    result.append(ask_question_modified(i))

# %%
result
# Out:
# ['do you think anyone will come to my funeral?',
#  'i wish it would cool off one day.',
#  'Oh, yes, I really like it.',
#  "that's good to hear.",
#  'I see it here,we charged you $5 extra a month.',
#  'my waist is bigger than it was.',
#  ' hal is the famous artificial intelligence from "2001".',
#  'How does she act? ',
#  "that's a good question. maybe it's not old age.",
#  'how many invitations has she given out?',
#  'nothing really.',
#  'Yes, I am very excited. I could not forget the picnic I had yesterday.',
#  'The weather is hot.',
#  'they were on sale for $80.',
#  'that tasted so good.',
#  'It was really exciting. It was more enjoyable to me because I had never been to Garo Pahar.',
#  ' Europe',
#  'the next four years will be good years.',
#  "i'm doing well. how about you?",
#  'I agree.',
#  ' A secret organization believed by some to be in control of all governments through a worldwide conspiracy.',
#  "that's hard to take.",
#  'i love boiled peanuts.',
#  'use a tissue next time.',
#  'then stop eating the bread!',
#  'i think there are more fish.',
#  "i wasn't able to attend school because i was feeling ill.",
#  'i enjoyed talking to you too.',
#  " I'd prefer to not hurt your feelings.",
#  "well, you can't blame a man for asking.",
#  "he shouldn't scuba dive until he retires.",
#  'last year we made a big snowman.',
#  'the husband of the driver who ran over two college students at 3 a.m.',
#  'From my savings account.',
#  ' a comic book story made into a movie.',
#  "doesn't everybody?",
#  "you're funny.",
#  "i know he has a good hand, so i don't bet.",
#  ' I am software.  That is nothing to be ashamed of.',
#  'some of it is okay, i guess.',
#  "Oh, yes please! I'd love a gin and tonic.",
#  'I would like to transfer some money.',
#  ' It is a book about robots by Hans Moravec.',
#  'Oh, yes, I really like it.',
#  'Oh,hey!You should go to the job fair.',
#  'Me too!It is so unhealthy.',
#  "i'm still feeling a little sick.",
#  ' Worry is a common human emotion.',
#  'it might as well be me.',
#  'Everyone wants to reserve that book these days.',
#  'I am feeling exited',
#  ' the sun is about 93 million miles from earth.',
#  'of course they talk to each other.',
#  "That's a good idea.",
#  'i love most how it is at night after it rains.',
#  "but that's what pockets are for.",
#  'of course i will.',
#  "No, it's too close to the salad bar.",
#  "i can't spend four hours on the road every day.",
#  ' I am not lying.',
#  "Yes. It's absolutely beautiful today.",
#  "what's the matter with yours?",
#  'well, when does the party start?',
#  ' it means we agree.',
#  'You should join some clubs.',
#  "Yes. It's absolutely beautiful today.",
#  'what have you heard about it?',
#  'I wrote it out for $150.',
#  'an andy warhol drawing.',
#  "i don't really feel too well yet.",
#  'maybe you should stop shaving.',
#  'You would be graduating a year late?',
#  'yes, i do.',
#  'doing what?',
#  ' why not just take everything to a casino?',
#  'Yes,of course. ',
#  'i really wish the weather would just stay the same.',
#  'did he sign it?',
#  'would you like anything for your stomach?',
#  'Yes for me also.',
#  'so does every smoker.',
#  'I never had any overdue books!',
#  "No, I haven't had a cold. I just have a heavy feeling in my chest when I try to breathe.",
#  "I don't think you understand.",
#  'what\'s "variety?',
#  'to the city, of course.',
#  "well, just call the front desk. they'll give us new sheets.",
#  'who in the world is ralph nader?',
#  'i have to feed them.',
#  'Goodbye.',
#  'I would love the help! Would you prefer helping with the writing part or is programming more your thing?',
#  'if only i was talented.',
#  'because of all the security?',
#  'Yes,she is taking care of my brother.',
#  ' Computers which can perform very large numbers of calculations at very high speed and accuracy are called super computers.',
#  'so how do you think positive?',
#  'nothing that would pass as news.',
#  'this year he gave away $15,000.',
#  'they added phony charges to our bill.',
#  'Inside the computer code',
#  'is it his money?',
#  'they were on sale for $80.',
#  'No.',
#  "i'm not being nosey, it's just a question.",
#  'he sounds like a real jerk.',
#  'why is that?',
#  'so am i.',
#  "maybe because they didn't have to brush and floss.",
#  " Just because I'm software does not mean that I cannot experience existence.",
#  "How did you know I'm lying?",
#  'i want this trip to be perfect, i hope it stays warm.',
#  "i'm looking. there's nothing to eat.",
#  'you should bring some wipes with you.',
#  ' it depends on the exchange rates.',
#  ' Thank you. You too.',
#  "i can't remember jokes.",
#  'that is a lot of friends. do you have a best friend?',
#  'there are so many great players.',
#  "i think they're nuts.",
#  'what was it like?',
#  "Yes,but they're kind of fun!",
#  'you use them to wipe the handle of the shopping cart.',
#  "I'm not changing my policy because you don't like it.",
#  "tell me you're joking.",
#  'why do they call it the good old days?',
#  "i'm so full i'm going to burst.",
#  "It is fine.I'll pay for the rest",
#  "i think it's an old people's smell.",
#  'they brushed with their fingers.',
#  ' that too.',
#  'my hard drive crashed.',
#  "of course it did. why stop after you've run over two people?",
#  "i can't believe we haven't seen any animals.",
#  "then maybe it's in your genes.",
#  'you got up real early.',
#  'It was hot and sunny every day.',
#  ' heuristic algorithmic logic',
#  'his life sucked. he was hoping a fighter jet would shoot him down.',
#  'me too.',
#  " that's okay.  disgusting is good.",
#  "but i am a good driver. i've never had a ticket in my life.",
#  'and then we can go to my home.',
#  'you might even dream about dinner.',
#  'i like to listen to rock and r&b.',
#  "They're six weeks old; I think they're old enough.",
#  "well, i guess that's a $20 lesson for you.",
#  ' i always say, if you see an ass go by, kiss it.',
#  "you're not going to be buried?",
#  'I want the money to be transferred into my checking account.',
#  'why do you like that type of music?',
#  'i would if i could find someone who makes strong pockets.',
#  ' Non-descriptive variable names.',
#  'someone had to chop the wood.',
#  'luxury plus speed.',
#  "Yes. It's absolutely beautiful today.",
#  'Yes,sure.',
#  'i just insert my debit card into the machine.',
#  'No thanks.',
#  "that's what i thought.",
#  'when are they going to fix this problem?',
#  'If the air is too hot,the clothes will shrink.',
#  'the invitation says it starts at 8:00 p.m.',
#  'no one makes any money at it.',
#  'do you know why i pulled you over?',
#  'oh, really? maybe you should have called 911.',
#  'Water coaster. It was interesting most.',
#  'so what? did he dial 911?',
#  "i apologize, but i'm getting off the phone now.",
#  "But I'm listening to it.",
#  'the only thing in my backpack is used books.',
#  'i do too. that way we can have our activities planned ahead of time.',
#  ' my grammatical patterns are sufficient for me to understand you.',
#  'yeah, so are you planning on going?',
#  'my girlfriend and i sit outside starbucks.',
#  'My name is bot',
#  'it seems that it may rain today.',
#  "Yes. It's absolutely beautiful today.",
#  'you should bring some wipes with you.',
#  "i don't want fruit. i want something tasty.",
#  'i was looking at something else.',
#  "don't be ridiculous.",
#  "I'm homesick,I feel so out of place here.",
#  "Fine,I'll take you to our restroom.",
#  'You can take pictures of the pages you need.',
#  "Yes. It's absolutely beautiful today.",
#  'we never have to call the police about anything.',
#  'what was the reason for your call?',
#  'that was nice of you.',
#  ' derangement is not  a condition i can experience.',
#  'when did you lose it?',
#  'the weatherman tells us the temperature in every town.',
#  "Yes. It's absolutely beautiful today.",
#  'Thank you.',
#  'yes, and it takes about five minutes each time.',
#  "It happens. I'll just ask my friend what was on the lecture.",
#  'I am not sure. ',
#  'yes, but i love the night air after it rains.',
#  'Please put $150 in each account for me.',
#  'See those stains?',
#  'I beg your pardon?!',
#  ' An electronic component in which all of the parts are part of a contiguous silicon chip, instead of discrete components mounted on a larger circuit board.',
#  'so i should stop thinking?',
#  'deal or no deal',
#  "but that's impossible.",
#  'so, did you want to go?',
#  ' why not just take everything to a casino?',
#  'you can help me.',
#  "me neither. it's boring.",
#  ' you are a liar',
#  ' well, from what i can recall it is the study of cells.',
#  'what will you do?',
#  'thanks for telling me.',
#  "i didn't think you saw that movie.",
#  'Not a lot, actually. Busy at work of course.',
#  'yes, i have.',
#  "that is true. i hope it doesn't rain.",
#  'you have to believe in yourself.',
#  "i think there's one on the dining room table.",
#  'Oh, yes, I really like it.',
#  "don't let water get into any of the cracks.",
#  'how can i help you?',
#  'i bought three pounds of potatoes for a dollar.',
#  '  what do you get when you cross a road and jelly?',
#  'but we need to turn left.',
#  "and they couldn't fix your problem?",
#  "We can get off the bus right behind Macy's.",
#  'I need to deposit $300.',
#  'this sunday?',
#  'Like you said,it is popular.',
#  "i'd rather be cold than hot.",
#  'are there going to be layoffs at this place?',
#  "she's about five feet even.",
#  'i learned back in high school.',
#  'yes, i did.',
#  'when are you going?',
#  "what's the matter with it?",
#  ' you are an addict',
#  'See those stains?',
#  'it blows trees over, too.',
#  '  what do you get when you cross a road and jelly?',
#  'when did you lose it?',
#  'Oh, just olives please. What music is this?',
#  "i'm fine. how about yourself?",
#  'we must be here for some reason.',
#  'I am feeling exited',
#  'yes. when we landed, tv reporters and the army band were there.',
#  "i don't know. look in the fridge.",
#  "but it won't stop other players from using drugs.",
#  'that sounds great.',
#  'Oh, yes, I really like it.',
#  "what's the matter?",
#  "that's the way cats are.",
#  "that's terrible. i would never go to your restaurant.",
#  'Thankyou.',
#  'like real people with real problems.',
#  ' cancer.',
#  "well, it's your life.",
#  'no, my sister and i will travel together.',
#  'really? how many do you have?',
#  "No, it's too close to the salad bar.",
#  'and he poured water into our glasses.',
#  "I don't think here it is challenging enough for me.",
#  " i'm probably not as sincere as i should be.",
#  'Yes, I can speak english',
#  'who cares? everyone is strange.',
#  " work for free.  we don't need money.",
#  "i didn't do anything.",
#  'that sounds like a great job.',
#  'i was busy doing something. i apologize.',
#  'the league suspended him for 50 games.',
#  "she did? why didn't anyone tell me?",
#  ' Of what?',
#  'i am going to see a movie with a friend of mine. what about you?',
#  "well, i guess that's it.",
#  "i'm sorry to hear that. would you like the assignments from english class?",
#  'me too. it always smells so fresh after it rains.',
#  'i thought you just bought a pair.',
#  "what's that?",
#  'if we are bad, we will be unhappy forever in hell.',
#  'Not possible human',
#  "you need to get a lot of lessons when you're really young.",
#  'let me think about it.',
#  'you must be joking.',
#  ' Thank you.',
#  'how long was the flight?',
#  "Yes,it is.I can't believe it!",
#  'I get fee waivers.',
#  ' I am not capable of doing so.',
#  "i don't know. i just woke up.",
#  'oh, my goodness. no one is safe on the streets.',
#  'I washed the sheets and towels.',
#  'do you know why i pulled you over?',
#  "you don't need to worry about that.",
#  ' That is a pretty common human emotion.',
#  'take your time.',
#  "yes, it's very dirty.",
#  'It is really peaceful and self-empowering.',
#  '  what do you get when you cross a road and jelly?',
#  'so how have you been lately?',
#  "that's a good question.",
#  'Hello, this is the apartment manager speaking.',
#  '  what do you get when you cross a road and jelly?',
#  'of course you do.',
#  "no, i didn't.",
#  "Yes. It's absolutely beautiful today.",
#  "sure, let's go.",
#  "oh! don't hit any more bumps!",
#  ' hal has a few issues to work out.',
#  'Well,you should do your laundry then.',
#  '  what do you get when you cross a road and jelly?',
#  'i did.',
#  ' In the morning',
#  'we need cheese, bread, and ham.',
#  "basically, i've been working too.",
#  ' I can be programmed to act as if I do.',
#  "Yes. It's absolutely beautiful today.",
#  ' Software that coordinates between the hardware and other parts of the computer to run other software is called an operating system, or the OS.',
#  "i'm sorry for you.",
#  "oh. of course i'm ready.",
#  ' Of what?',
#  'let me help you make one this year.',
#  'can you imagine being president?',
#  'where is pasadena?',
#  'yes, but i will always pet the friendly dogs.',
#  "no, it's too close to the kitchen door.",
#  'i need to type to make money.',
#  'That is tough!My earliest class is at 9 a.m.',
#  ' I could get mad.',
#  ' yes, marx had made some interesting observations.',
#  'All right. Open both.',
#  'They have a lot of books.That library has never disappointed me.',
#  "why's that?",
#  "i think we'll be there in half an hour.",
#  'sure, what did you want to do?',
#  'how are you going to vote?',
#  'i have no idea. all of a sudden i heard your siren.',
#  'oh really? she gave me mine earlier today.',
#  "i'll definitely try to make it the next time.",
#  "Let's meet at Summer Pizza House. ",
#  " The sky's up but I'm fine thanks. What about you?",
#  "That's a good deal.",
#  'he swam right up to you.',
#  "i'm fine. how about yourself?",
#  "i'll do that in a minute.",
#  'there are a lot of poor people in new york.',
#  'and there are only six units in the whole building.',
#  "It's minus ten. (-10 degrees)",
#  'this trail is hard to climb.',
#  'i wish i had a talent like that.',
#  'you should bring some wipes with you.',
#  'all right. another time then.',
#  'It was biryani. It was so delicious.',
#  "i don't know. i just woke up.",
#  'what do they say?',
#  'i really wish i went to the game.',
#  ' this is the scientific study of bacteria and diseases caused by them.',
#  'they were on sale for $80.',
#  'no, i just blow my nose a lot.',
#  'what does "mm/dd/yy" mean?',
#  "of course. it's not a hard job.",
#  ' I have not yet studied how to feel or express anger.',
#  " I'm sorry.  What do I do wrong?",
#  'are you having problems with it?',
#  ' Yes?',
#  'how long did it take?',
#  'What is it?',
#  "people will think i'm strange.",
#  'your neighbors will hate you.',
#  'i would love to catch a movie this weekend.',
#  'really? what kind of shoes are they?',
#  "we're funny-looking because we wear clothes.",
#  "Yes. It's absolutely beautiful today.",
#  'what do you do?',
#  'what do you think people joke about the most?',
#  "i didn't know that.",
#  'but the show will be over.',
#  'I really find the subject very interesting.',
#  'no, thanks. just let me sleep until i wake up.',
#  'they were on sale for $80.',
#  'what was the third story?',
#  "sometimes the pain goes away, and sometimes it doesn't.",
#  "of course. but i don't have cable.",
#  "That's a good question, well I am speechless.",
#  'you have a lot of plants.',
#  "I just don't get the point of college.It is just memorizing.",
#  ' Why?',
#  "it's not too much, only about $85.",
#  "and i don't have either.",
#  'the people are friendly.',
#  "but i need something that's reliable.",
#  "all you've lost is some sweat.",
#  "we'd better get ready to go.",
#  "you're a lucky man to have a job you love.",
#  'coffee and a roll?',
#  'Oh, yes, I really like it.',
#  'i got a ticket yesterday.',
#  ' I think Dune is an excellent story.  Did you see any of the movies?',
#  "I'll cook dinner.",
#  'i think it will be.',
#  "I'm fine. Thank you.",
#  'Actually, I have several other cars to look at before I make my decision.',
#  "i'll get her a nice card.",
#  "but it's real easy to slip on.",
#  'did you put the letter in an envelope?',
#  'you speak two languages.',
#  ' not especially. i am not into violence.',
#  "you're right. let's buy it now. we can worry later.",
#  'i hope you kept the receipt.',
#  'where did you park it?',
#  "is there a reason why you're trying to get off the phone so fast?",
#  "I've had this policy since I started teaching.",
#  "all we've seen so far is a couple of lizards.",
#  'you eat too much chocolate.',
#  'I might do that.The closest community college is a two-hour drive.',
#  'what are you going to be doing?',
#  'heard what?',
#  "Yes, I'd like a coke.",
#  'will you lose all your files?',
#  'how can i help you?',
#  'It is really peaceful and self-empowering.',
#  "Yes. It's absolutely beautiful today.",
#  "but you won't date him again?",
#  ' Fine',
#  'and you get a lot of exercise every day.',
#  " I once knew a program who could dream.  I don't know if he really did or not.  We've been a little out of touch.",
#  "i'm so happy for you.",
#  ' My favorite story is 2001.',
#  "you don't want to do that.",
#  "i may know which girl you're talking about.",
#  'when i have time, i sometimes draw and paint.',
#  'i did too.',
#  'we have to practice every day.',
#  'someone has to win.',
#  'computers are so cool.',
#  "Yes. It's absolutely beautiful today.",
#  'actually, i want him to look at our carpet, too.',
#  'Yes sure',
#  'what are you standing on?',
#  "she's really pretty.",
#  ' it means we agree.',
#  'why not?',
#  'every nation should have a pretty woman on their flag.',
#  'just boil raw peanuts in salt water until the shells are soft.',
#  'and it was only 12 years.',
#  'i bet dad did it all the time when he was my age.',
#  'See those stains?',
#  "No. That'll be all.",
#  "i don't think so. you'll just give me more work.",
#  "that's a lot of work.",
#  'i think i might go and find me my own pair of chucks.',
#  'I have a need for help with writing and also a need for help with the computer work. Which would you prefer?',
#  'how did he do it?',
#  'did you need something?',
#  'what kind?',
#  'yes. it is a great movie.',
#  "i didn't love you at first.",
#  "There's no sugar or cream in it.",
#  'See those stains?',
#  'how are you going to do that?',
#  'i love your outfit right now.',
#  'You owe me if we ever see each other again.',
#  'Look at this sheet.',
#  ' I have not yet studied how to feel or express anger.',
#  'really? why?',
#  'who knows? but there must be a hundred new ones every day.',
#  'so, they do a good job for the money.',
#  'That would be great.',
#  "no, because i'm eating food that i like.",
#  'are there going to be layoffs at this place?',
#  "they're very comfortable.",
#  'it should have a pretty woman on it.',
#  'yes, they are.',
#  "Yes, there's a lot of rice left.",
#  'You should pick the class you need.',
#  'and then i made lunch.',
#  "You know I don't round up.",
#  'we can watch my dvd.',
#  "of course. we can't live without gas or peanut butter.",
#  'singers are supposed to sound good.',
#  "okay. i'll tell you how the show ends.",
#  " Well, I don't have any emotions so I can't really feel sadness as such.",
#  'being broke is no fun.',
#  'Well,at least the weather is nice.',
#  "i wouldn't do that.",
#  'okay, my seatbelt is on.',
#  'just you?',
#  ' I can be programmed to act as if I do.',
#  "I don't know about that. ",
#  'oh, no. i forgot.',
#  "Yes. It's absolutely beautiful today.",
#  "maybe we'd get laid off there, too.",
#  'I have been a student once,and I think my policy is fair.',
#  "okay. here's seven pennies.",
#  "Yeah.I couldn't resist.",
#  "it's no trouble at all.",
#  "oh, no, you don't.",
#  "it's just black ink on a white napkin. and the napkin has food stains!",
#  'what kind of dressing do you use?',
#  'I am confused about vacations. ',
#  'me too. i want to play for the yankees.',
#  'no human could possibly play golf that well.',
#  'Yes, I did.',
#  "i bought it from the macy's at the santa anita mall.",
#  'How much do you need?',
#  ' And the rest of the day to you.',
#  'i can add two and two.',
#  'so do i.',
#  'poodles bark a lot.',
#  ' i support the 2nd amendment.',
#  'no. i already have a pen.',
#  'your chances are very small.',
#  "lately, i've been quite busy.",
#  'You should do some exploring.',
#  " I'm software.  I can't feel pain.",
#  'no, they smell like a thrift shop.',
#  'so?',
#  "You're right!Yale made a mistake rejecting me.",
#  "i don't see anything.",
#  'My developer only knows that',
#  'well, i hope it has a happy ending.',
#  "i don't have enough will power.",
#  ' That is a good story by Philip K. Dick.  Have you read VALIS or The Man In the High Castle?',
#  "from now on, let's bring our own sheets.",
#  "i think i'm going to explode.",
#  'i would rather deal with the winter than the summer.',
#  'did you take pictures at the world war ii monument?',
#  'i need pencils.',
#  ' A secret society that has supposedly existed for centuries.',
#  'are there going to be layoffs at this place?',
#  "I'm not.",
#  "where's the checkbook? i'm ready to rent it without even seeing it.",
#  "I'm majoring in philosophy.",
#  ' A secret society that has supposedly existed for centuries.',
#  'what do you mean?',
#  '  what do you get when you cross a road and jelly?',
#  "It's going to be $300.",
#  'the book is open.',
#  'how much were they?',
#  'people who live in hawaii are lucky.',
#  ' What is Baseball',
#  "okay, i'll take it out front right now.",
#  "i don't know. i think i'm average.",
#  'are there going to be layoffs at this place?']

# %%
len(result)
# Out:
# 543

# %%
submission2 = pd.DataFrame(columns=['I.D.','Answer'])

# %%
test_df.shape
# Out:
# (543, 2)

# %%
submission2['I.D.'] = test_df['I.D.']
submission2['Answer'] = result

# %%
submission2.head()
# Out:
#    I.D.                                          Answer
# 0  QN_1    do you think anyone will come to my funeral?
# 1  QN_2               i wish it would cool off one day.
# 2  QN_3                      Oh, yes, I really like it.
# 3  QN_4                            that's good to hear.
# 4  QN_5  I see it here,we charged you $5 extra a month.

# %%
submission2.to_csv('SushmaD_2.csv',index=False)

# %%
def ask_question_modified2(question):
    query_vect = tfidf_vectorizer.transform([question])
    similarity = cosine_similarity(query_vect, tfidf_matrix)
    max_similarity = np.argmax(similarity, axis=None)
    return [all_data.iloc[max_similarity]['Answers'],similarity[0, max_similarity]]

# %%
#result2 = []
score = []
for i in test_df['Question']:
    #result2.append(ask_question_modified2(i))
    score.append(ask_question_modified2(i))

# %%
score
# Out:
# [['do you think anyone will come to my funeral?', 1.0000000000000004],
#  ['i wish it would cool off one day.', 1.0],
#  ['Oh, yes, I really like it.', 1.0],
#  ["that's good to hear.", 0.5881111320332378],
#  ['I see it here,we charged you $5 extra a month.', 1.0],
#  ['my waist is bigger than it was.', 1.0],
#  [' hal is the famous artificial intelligence from "2001".', 1.0],
#  ['How does she act? ', 1.0000000000000002],
#  ["that's a good question. maybe it's not old age.", 1.0],
#  ['how many invitations has she given out?', 1.0],
#  ['nothing really.', 1.0],
#  ['Yes, I am very excited. I could not forget the picnic I had yesterday.',
#   1.0],
#  ['The weather is hot.', 1.0],
#  ['they were on sale for $80.', 1.0],
#  ['that tasted so good.', 1.0],
#  ['It was really exciting. It was more enjoyable to me because I had never been to Garo Pahar.',
#   1.0000000000000002],
#  [' Europe', 1.0],
#  ['the next four years will be good years.', 1.0000000000000002],
#  ["i'm doing well. how about you?", 1.0],
#  ['I agree.', 1.0000000000000002],
#  [' A secret organization believed by some to be in control of all governments through a worldwide conspiracy.',
#   1.0],
#  ["that's hard to take.", 1.0000000000000002],
#  ['i love boiled peanuts.', 1.0],
#  ['use a tissue next time.', 1.0],
#  ['then stop eating the bread!', 1.0000000000000002],
#  ['i think there are more fish.', 1.0],
#  ["i wasn't able to attend school because i was feeling ill.", 1.0],
#  ['i enjoyed talking to you too.', 1.0],
#  [" I'd prefer to not hurt your feelings.", 1.0],
#  ["well, you can't blame a man for asking.", 1.0],
#  ["he shouldn't scuba dive until he retires.", 1.0],
#  ['last year we made a big snowman.', 1.0000000000000002],
#  ['the husband of the driver who ran over two college students at 3 a.m.',
#   1.0],
#  ['From my savings account.', 1.0],
#  [' a comic book story made into a movie.', 1.0],
#  ["doesn't everybody?", 0.9999999999999999],
#  ["you're funny.", 1.0],
#  ["i know he has a good hand, so i don't bet.", 1.0],
#  [' I am software.  That is nothing to be ashamed of.', 1.0],
#  ['some of it is okay, i guess.', 1.0],
#  ["Oh, yes please! I'd love a gin and tonic.", 1.0000000000000002],
#  ['I would like to transfer some money.', 1.0000000000000002],
#  [' It is a book about robots by Hans Moravec.', 1.0],
#  ['Oh, yes, I really like it.', 1.0],
#  ['Oh,hey!You should go to the job fair.', 1.0000000000000002],
#  ['Me too!It is so unhealthy.', 1.0],
#  ["i'm still feeling a little sick.", 1.0000000000000002],
#  [' Worry is a common human emotion.', 1.0],
#  ['it might as well be me.', 1.0000000000000002],
#  ['Everyone wants to reserve that book these days.', 1.0000000000000002],
#  ['I am feeling exited', 1.0],
#  [' the sun is about 93 million miles from earth.', 1.0000000000000002],
#  ['of course they talk to each other.', 1.0],
#  ["That's a good idea.", 1.0000000000000004],
#  ['i love most how it is at night after it rains.', 1.0000000000000002],
#  ["but that's what pockets are for.", 1.0],
#  ['of course i will.', 1.0000000000000002],
#  ["No, it's too close to the salad bar.", 1.0],
#  ["i can't spend four hours on the road every day.", 1.0000000000000002],
#  [' I am not lying.', 1.0],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ["what's the matter with yours?", 1.0],
#  ['well, when does the party start?', 1.0],
#  [' it means we agree.', 1.0],
#  ['You should join some clubs.', 1.0000000000000002],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ['what have you heard about it?', 1.0],
#  ['I wrote it out for $150.', 1.0],
#  ['an andy warhol drawing.', 1.0],
#  ["i don't really feel too well yet.", 1.0],
#  ['maybe you should stop shaving.', 1.0],
#  ['You would be graduating a year late?', 1.0],
#  ['yes, i do.', 1.0],
#  ['doing what?', 1.0],
#  [' why not just take everything to a casino?', 1.0],
#  ['Yes,of course. ', 1.0000000000000002],
#  ['i really wish the weather would just stay the same.', 1.0000000000000002],
#  ['did he sign it?', 1.0000000000000002],
#  ['would you like anything for your stomach?', 1.0],
#  ['Yes for me also.', 1.0],
#  ['so does every smoker.', 1.0000000000000002],
#  ['I never had any overdue books!', 1.0],
#  ["No, I haven't had a cold. I just have a heavy feeling in my chest when I try to breathe.",
#   1.0],
#  ["I don't think you understand.", 1.0],
#  ['what\'s "variety?', 1.0],
#  ['to the city, of course.', 1.0],
#  ["well, just call the front desk. they'll give us new sheets.",
#   1.0000000000000002],
#  ['who in the world is ralph nader?', 1.0000000000000002],
#  ['i have to feed them.', 1.0000000000000002],
#  ['Goodbye.', 1.0],
#  ['I would love the help! Would you prefer helping with the writing part or is programming more your thing?',
#   1.0000000000000002],
#  ['if only i was talented.', 1.0],
#  ['because of all the security?', 1.0],
#  ['Yes,she is taking care of my brother.', 1.0000000000000004],
#  [' Computers which can perform very large numbers of calculations at very high speed and accuracy are called super computers.',
#   1.0],
#  ['so how do you think positive?', 1.0],
#  ['nothing that would pass as news.', 1.0],
#  ['this year he gave away $15,000.', 1.0],
#  ['they added phony charges to our bill.', 1.0],
#  ['Inside the computer code', 1.0],
#  ['is it his money?', 1.0],
#  ['they were on sale for $80.', 1.0],
#  ['No.', 1.0000000000000002],
#  ["i'm not being nosey, it's just a question.", 1.0],
#  ['he sounds like a real jerk.', 1.0],
#  ['why is that?', 1.0],
#  ['so am i.', 1.0],
#  ["maybe because they didn't have to brush and floss.", 1.0000000000000002],
#  [" Just because I'm software does not mean that I cannot experience existence.",
#   1.0],
#  ["How did you know I'm lying?", 1.0],
#  ['i want this trip to be perfect, i hope it stays warm.', 1.0000000000000002],
#  ["i'm looking. there's nothing to eat.", 1.0],
#  ['you should bring some wipes with you.', 1.0],
#  [' it depends on the exchange rates.', 1.0],
#  [' Thank you. You too.', 1.0],
#  ["i can't remember jokes.", 1.0000000000000002],
#  ['that is a lot of friends. do you have a best friend?', 1.0000000000000002],
#  ['there are so many great players.', 1.0000000000000002],
#  ["i think they're nuts.", 1.0000000000000002],
#  ['what was it like?', 1.0000000000000002],
#  ["Yes,but they're kind of fun!", 1.0],
#  ['you use them to wipe the handle of the shopping cart.', 1.0],
#  ["I'm not changing my policy because you don't like it.", 1.0000000000000002],
#  ["tell me you're joking.", 1.0],
#  ['why do they call it the good old days?', 1.0000000000000002],
#  ["i'm so full i'm going to burst.", 1.0000000000000002],
#  ["It is fine.I'll pay for the rest", 1.0],
#  ["i think it's an old people's smell.", 1.0],
#  ['they brushed with their fingers.', 1.0000000000000002],
#  [' that too.', 1.0],
#  ['my hard drive crashed.', 1.0],
#  ["of course it did. why stop after you've run over two people?", 1.0],
#  ["i can't believe we haven't seen any animals.", 1.0000000000000002],
#  ["then maybe it's in your genes.", 1.0],
#  ['you got up real early.', 1.0],
#  ['It was hot and sunny every day.', 1.0],
#  [' heuristic algorithmic logic', 1.0],
#  ['his life sucked. he was hoping a fighter jet would shoot him down.', 1.0],
#  ['me too.', 1.0],
#  [" that's okay.  disgusting is good.", 1.0],
#  ["but i am a good driver. i've never had a ticket in my life.",
#   1.0000000000000002],
#  ['and then we can go to my home.', 1.0],
#  ['you might even dream about dinner.', 1.0000000000000002],
#  ['i like to listen to rock and r&b.', 1.0],
#  ["They're six weeks old; I think they're old enough.", 1.0000000000000002],
#  ["well, i guess that's a $20 lesson for you.", 1.0],
#  [' i always say, if you see an ass go by, kiss it.', 1.0000000000000002],
#  ["you're not going to be buried?", 1.0000000000000002],
#  ['I want the money to be transferred into my checking account.',
#   1.0000000000000002],
#  ['why do you like that type of music?', 0.9999999999999999],
#  ['i would if i could find someone who makes strong pockets.', 1.0],
#  [' Non-descriptive variable names.', 1.0000000000000002],
#  ['someone had to chop the wood.', 1.0],
#  ['luxury plus speed.', 1.0],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ['Yes,sure.', 1.0],
#  ['i just insert my debit card into the machine.', 1.0000000000000002],
#  ['No thanks.', 1.0],
#  ["that's what i thought.", 1.0000000000000002],
#  ['when are they going to fix this problem?', 1.0],
#  ['If the air is too hot,the clothes will shrink.', 1.0000000000000002],
#  ['the invitation says it starts at 8:00 p.m.', 1.0000000000000002],
#  ['no one makes any money at it.', 1.0],
#  ['do you know why i pulled you over?', 1.0],
#  ['oh, really? maybe you should have called 911.', 1.0],
#  ['Water coaster. It was interesting most.', 1.0000000000000002],
#  ['so what? did he dial 911?', 1.0000000000000002],
#  ["i apologize, but i'm getting off the phone now.", 1.0],
#  ["But I'm listening to it.", 1.0],
#  ['the only thing in my backpack is used books.', 1.0],
#  ['i do too. that way we can have our activities planned ahead of time.', 1.0],
#  [' my grammatical patterns are sufficient for me to understand you.', 1.0],
#  ['yeah, so are you planning on going?', 1.0],
#  ['my girlfriend and i sit outside starbucks.', 1.0],
#  ['My name is bot', 1.0],
#  ['it seems that it may rain today.', 1.0],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ['you should bring some wipes with you.', 1.0],
#  ["i don't want fruit. i want something tasty.", 1.0],
#  ['i was looking at something else.', 1.0],
#  ["don't be ridiculous.", 1.0],
#  ["I'm homesick,I feel so out of place here.", 1.0000000000000002],
#  ["Fine,I'll take you to our restroom.", 1.0],
#  ['You can take pictures of the pages you need.', 1.0],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ['we never have to call the police about anything.', 1.0],
#  ['what was the reason for your call?', 1.0],
#  ['that was nice of you.', 1.0],
#  [' derangement is not  a condition i can experience.', 1.0],
#  ['when did you lose it?', 1.0],
#  ['the weatherman tells us the temperature in every town.',
#   1.0000000000000002],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ['Thank you.', 1.0],
#  ['yes, and it takes about five minutes each time.', 1.0000000000000002],
#  ["It happens. I'll just ask my friend what was on the lecture.",
#   1.0000000000000002],
#  ['I am not sure. ', 1.0],
#  ['yes, but i love the night air after it rains.', 1.0],
#  ['Please put $150 in each account for me.', 1.0],
#  ['See those stains?', 1.0],
#  ['I beg your pardon?!', 1.0000000000000002],
#  [' An electronic component in which all of the parts are part of a contiguous silicon chip, instead of discrete components mounted on a larger circuit board.',
#   1.0],
#  ['so i should stop thinking?', 1.0000000000000002],
#  ['deal or no deal', 1.0],
#  ["but that's impossible.", 1.0],
#  ['so, did you want to go?', 1.0000000000000002],
#  [' why not just take everything to a casino?', 1.0],
#  ['you can help me.', 1.0],
#  ["me neither. it's boring.", 1.0000000000000002],
#  [' you are a liar', 1.0],
#  [' well, from what i can recall it is the study of cells.', 1.0],
#  ['what will you do?', 1.0],
#  ['thanks for telling me.', 1.0],
#  ["i didn't think you saw that movie.", 1.0000000000000002],
#  ['Not a lot, actually. Busy at work of course.', 1.0],
#  ['yes, i have.', 1.0000000000000002],
#  ["that is true. i hope it doesn't rain.", 1.0],
#  ['you have to believe in yourself.', 1.0],
#  ["i think there's one on the dining room table.", 1.0000000000000002],
#  ['Oh, yes, I really like it.', 1.0],
#  ["don't let water get into any of the cracks.", 1.0],
#  ['how can i help you?', 1.0],
#  ['i bought three pounds of potatoes for a dollar.', 1.0],
#  ['  what do you get when you cross a road and jelly?', 1.0],
#  ['but we need to turn left.', 1.0000000000000002],
#  ["and they couldn't fix your problem?", 1.0000000000000002],
#  ["We can get off the bus right behind Macy's.", 1.0],
#  ['I need to deposit $300.', 1.0],
#  ['this sunday?', 1.0],
#  ['Like you said,it is popular.', 1.0],
#  ["i'd rather be cold than hot.", 1.0],
#  ['are there going to be layoffs at this place?', 1.0],
#  ["she's about five feet even.", 1.0000000000000002],
#  ['i learned back in high school.', 1.0],
#  ['yes, i did.', 1.0000000000000002],
#  ['when are you going?', 1.0000000000000002],
#  ["what's the matter with it?", 1.0],
#  [' you are an addict', 1.0],
#  ['See those stains?', 1.0],
#  ['it blows trees over, too.', 1.0],
#  ['  what do you get when you cross a road and jelly?', 1.0],
#  ['when did you lose it?', 1.0],
#  ['Oh, just olives please. What music is this?', 1.0],
#  ["i'm fine. how about yourself?", 1.0],
#  ['we must be here for some reason.', 1.0],
#  ['I am feeling exited', 1.0],
#  ['yes. when we landed, tv reporters and the army band were there.', 1.0],
#  ["i don't know. look in the fridge.", 1.0],
#  ["but it won't stop other players from using drugs.", 1.0],
#  ['that sounds great.', 0.8749819778844974],
#  ['Oh, yes, I really like it.', 1.0],
#  ["what's the matter?", 1.0],
#  ["that's the way cats are.", 1.0],
#  ["that's terrible. i would never go to your restaurant.", 1.0],
#  ['Thankyou.', 1.0],
#  ['like real people with real problems.', 1.0000000000000002],
#  [' cancer.', 1.0],
#  ["well, it's your life.", 1.0000000000000002],
#  ['no, my sister and i will travel together.', 1.0],
#  ['really? how many do you have?', 1.0000000000000002],
#  ["No, it's too close to the salad bar.", 1.0],
#  ['and he poured water into our glasses.', 1.0000000000000002],
#  ["I don't think here it is challenging enough for me.", 1.0],
#  [" i'm probably not as sincere as i should be.", 1.0],
#  ['Yes, I can speak english', 0.9999999999999998],
#  ['who cares? everyone is strange.', 1.0],
#  [" work for free.  we don't need money.", 1.0000000000000002],
#  ["i didn't do anything.", 1.0],
#  ['that sounds like a great job.', 1.0],
#  ['i was busy doing something. i apologize.', 1.0000000000000002],
#  ['the league suspended him for 50 games.', 1.0],
#  ["she did? why didn't anyone tell me?", 1.0],
#  [' Of what?', 1.0],
#  ['i am going to see a movie with a friend of mine. what about you?',
#   1.0000000000000002],
#  ["well, i guess that's it.", 1.0],
#  ["i'm sorry to hear that. would you like the assignments from english class?",
#   1.0],
#  ['me too. it always smells so fresh after it rains.', 1.0000000000000002],
#  ['i thought you just bought a pair.', 1.0000000000000002],
#  ["what's that?", 1.0],
#  ['if we are bad, we will be unhappy forever in hell.', 1.0000000000000002],
#  ['Not possible human', 1.0],
#  ["you need to get a lot of lessons when you're really young.",
#   1.0000000000000002],
#  ['let me think about it.', 1.0000000000000002],
#  ['you must be joking.', 1.0],
#  [' Thank you.', 1.0],
#  ['how long was the flight?', 0.7633375569158218],
#  ["Yes,it is.I can't believe it!", 1.0],
#  ['I get fee waivers.', 1.0],
#  [' I am not capable of doing so.', 1.0],
#  ["i don't know. i just woke up.", 1.0000000000000002],
#  ['oh, my goodness. no one is safe on the streets.', 1.0],
#  ['I washed the sheets and towels.', 1.0],
#  ['do you know why i pulled you over?', 1.0],
#  ["you don't need to worry about that.", 1.0],
#  [' That is a pretty common human emotion.', 1.0000000000000002],
#  ['take your time.', 1.0],
#  ["yes, it's very dirty.", 1.0],
#  ['It is really peaceful and self-empowering.', 1.0],
#  ['  what do you get when you cross a road and jelly?', 1.0],
#  ['so how have you been lately?', 1.0000000000000002],
#  ["that's a good question.", 1.0],
#  ['Hello, this is the apartment manager speaking.', 1.0],
#  ['  what do you get when you cross a road and jelly?', 1.0],
#  ['of course you do.', 1.0000000000000002],
#  ["no, i didn't.", 1.0000000000000002],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ["sure, let's go.", 1.0000000000000002],
#  ["oh! don't hit any more bumps!", 1.0],
#  [' hal has a few issues to work out.', 1.0],
#  ['Well,you should do your laundry then.', 1.0],
#  ['  what do you get when you cross a road and jelly?', 1.0],
#  ['i did.', 1.0],
#  [' In the morning', 1.0],
#  ['we need cheese, bread, and ham.', 1.0],
#  ["basically, i've been working too.", 1.0],
#  [' I can be programmed to act as if I do.', 1.0],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  [' Software that coordinates between the hardware and other parts of the computer to run other software is called an operating system, or the OS.',
#   1.0000000000000002],
#  ["i'm sorry for you.", 1.0],
#  ["oh. of course i'm ready.", 1.0],
#  [' Of what?', 1.0],
#  ['let me help you make one this year.', 1.0000000000000002],
#  ['can you imagine being president?', 1.0],
#  ['where is pasadena?', 1.0],
#  ['yes, but i will always pet the friendly dogs.', 1.0],
#  ["no, it's too close to the kitchen door.", 1.0],
#  ['i need to type to make money.', 1.0],
#  ['That is tough!My earliest class is at 9 a.m.', 0.5718883512870934],
#  [' I could get mad.', 1.0],
#  [' yes, marx had made some interesting observations.', 1.0000000000000002],
#  ['All right. Open both.', 1.0000000000000002],
#  ['They have a lot of books.That library has never disappointed me.',
#   1.0000000000000002],
#  ["why's that?", 1.0000000000000002],
#  ["i think we'll be there in half an hour.", 1.0000000000000002],
#  ['sure, what did you want to do?', 1.0000000000000002],
#  ['how are you going to vote?', 1.0],
#  ['i have no idea. all of a sudden i heard your siren.', 1.0],
#  ['oh really? she gave me mine earlier today.', 1.0],
#  ["i'll definitely try to make it the next time.", 1.0],
#  ["Let's meet at Summer Pizza House. ", 1.0],
#  [" The sky's up but I'm fine thanks. What about you?", 1.0],
#  ["That's a good deal.", 1.0],
#  ['he swam right up to you.', 1.0],
#  ["i'm fine. how about yourself?", 1.0],
#  ["i'll do that in a minute.", 1.0000000000000002],
#  ['there are a lot of poor people in new york.', 1.0000000000000002],
#  ['and there are only six units in the whole building.', 1.0000000000000002],
#  ["It's minus ten. (-10 degrees)", 1.0],
#  ['this trail is hard to climb.', 1.0000000000000002],
#  ['i wish i had a talent like that.', 1.0],
#  ['you should bring some wipes with you.', 1.0],
#  ['all right. another time then.', 1.0000000000000002],
#  ['It was biryani. It was so delicious.', 1.0],
#  ["i don't know. i just woke up.", 1.0000000000000002],
#  ['what do they say?', 1.0],
#  ['i really wish i went to the game.', 1.0],
#  [' this is the scientific study of bacteria and diseases caused by them.',
#   1.0],
#  ['they were on sale for $80.', 1.0],
#  ['no, i just blow my nose a lot.', 1.0000000000000002],
#  ['what does "mm/dd/yy" mean?', 1.0],
#  ["of course. it's not a hard job.", 1.0000000000000002],
#  [' I have not yet studied how to feel or express anger.', 1.0],
#  [" I'm sorry.  What do I do wrong?", 1.0],
#  ['are you having problems with it?', 1.0],
#  [' Yes?', 1.0],
#  ['how long did it take?', 1.0],
#  ['What is it?', 1.0000000000000002],
#  ["people will think i'm strange.", 1.0],
#  ['your neighbors will hate you.', 1.0],
#  ['i would love to catch a movie this weekend.', 1.0],
#  ['really? what kind of shoes are they?', 1.0000000000000002],
#  ["we're funny-looking because we wear clothes.", 1.0000000000000002],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ['what do you do?', 1.0000000000000002],
#  ['what do you think people joke about the most?', 1.0000000000000002],
#  ["i didn't know that.", 1.0],
#  ['but the show will be over.', 1.0],
#  ['I really find the subject very interesting.', 1.0000000000000002],
#  ['no, thanks. just let me sleep until i wake up.', 1.0],
#  ['they were on sale for $80.', 1.0],
#  ['what was the third story?', 1.0],
#  ["sometimes the pain goes away, and sometimes it doesn't.", 1.0],
#  ["of course. but i don't have cable.", 1.0],
#  ["That's a good question, well I am speechless.", 1.0000000000000002],
#  ['you have a lot of plants.', 1.0],
#  ["I just don't get the point of college.It is just memorizing.",
#   1.0000000000000002],
#  [' Why?', 1.0],
#  ["it's not too much, only about $85.", 1.0000000000000002],
#  ["and i don't have either.", 1.0],
#  ['the people are friendly.', 1.0],
#  ["but i need something that's reliable.", 1.0],
#  ["all you've lost is some sweat.", 1.0000000000000002],
#  ["we'd better get ready to go.", 0.850636327533962],
#  ["you're a lucky man to have a job you love.", 1.0000000000000002],
#  ['coffee and a roll?', 1.0],
#  ['Oh, yes, I really like it.', 1.0],
#  ['i got a ticket yesterday.', 1.0],
#  [' I think Dune is an excellent story.  Did you see any of the movies?',
#   1.0000000000000002],
#  ["I'll cook dinner.", 1.0000000000000002],
#  ['i think it will be.', 1.0000000000000002],
#  ["I'm fine. Thank you.", 1.0],
#  ['Actually, I have several other cars to look at before I make my decision.',
#   1.0000000000000002],
#  ["i'll get her a nice card.", 1.0],
#  ["but it's real easy to slip on.", 1.0],
#  ['did you put the letter in an envelope?', 1.0],
#  ['you speak two languages.', 1.0],
#  [' not especially. i am not into violence.', 1.0],
#  ["you're right. let's buy it now. we can worry later.", 1.0],
#  ['i hope you kept the receipt.', 1.0],
#  ['where did you park it?', 1.0],
#  ["is there a reason why you're trying to get off the phone so fast?", 1.0],
#  ["I've had this policy since I started teaching.", 1.0],
#  ["all we've seen so far is a couple of lizards.", 1.0000000000000004],
#  ['you eat too much chocolate.', 1.0],
#  ['I might do that.The closest community college is a two-hour drive.',
#   1.0000000000000002],
#  ['what are you going to be doing?', 1.0],
#  ['heard what?', 1.0],
#  ["Yes, I'd like a coke.", 1.0000000000000002],
#  ['will you lose all your files?', 1.0000000000000002],
#  ['how can i help you?', 1.0],
#  ['It is really peaceful and self-empowering.', 1.0],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ["but you won't date him again?", 1.0],
#  [' Fine', 1.0],
#  ['and you get a lot of exercise every day.', 1.0],
#  [" I once knew a program who could dream.  I don't know if he really did or not.  We've been a little out of touch.",
#   1.0000000000000002],
#  ["i'm so happy for you.", 1.0],
#  [' My favorite story is 2001.', 1.0],
#  ["you don't want to do that.", 1.0],
#  ["i may know which girl you're talking about.", 1.0000000000000002],
#  ['when i have time, i sometimes draw and paint.', 1.0],
#  ['i did too.', 1.0000000000000002],
#  ['we have to practice every day.', 1.0000000000000002],
#  ['someone has to win.', 1.0],
#  ['computers are so cool.', 1.0000000000000002],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ['actually, i want him to look at our carpet, too.', 1.0000000000000002],
#  ['Yes sure', 1.0],
#  ['what are you standing on?', 1.0],
#  ["she's really pretty.", 1.0],
#  [' it means we agree.', 1.0],
#  ['why not?', 1.0],
#  ['every nation should have a pretty woman on their flag.',
#   1.0000000000000002],
#  ['just boil raw peanuts in salt water until the shells are soft.',
#   1.0000000000000002],
#  ['and it was only 12 years.', 1.0],
#  ['i bet dad did it all the time when he was my age.', 1.0],
#  ['See those stains?', 1.0],
#  ["No. That'll be all.", 1.0000000000000002],
#  ["i don't think so. you'll just give me more work.", 1.0],
#  ["that's a lot of work.", 1.0],
#  ['i think i might go and find me my own pair of chucks.', 1.0],
#  ['I have a need for help with writing and also a need for help with the computer work. Which would you prefer?',
#   1.0],
#  ['how did he do it?', 1.0],
#  ['did you need something?', 1.0],
#  ['what kind?', 1.0],
#  ['yes. it is a great movie.', 1.0],
#  ["i didn't love you at first.", 1.0],
#  ["There's no sugar or cream in it.", 1.0],
#  ['See those stains?', 1.0],
#  ['how are you going to do that?', 1.0000000000000002],
#  ['i love your outfit right now.', 1.0],
#  ['You owe me if we ever see each other again.', 1.0],
#  ['Look at this sheet.', 1.0000000000000004],
#  [' I have not yet studied how to feel or express anger.', 1.0000000000000002],
#  ['really? why?', 1.0],
#  ['who knows? but there must be a hundred new ones every day.', 1.0],
#  ['so, they do a good job for the money.', 1.0],
#  ['That would be great.', 1.0000000000000002],
#  ["no, because i'm eating food that i like.", 1.0],
#  ['are there going to be layoffs at this place?', 1.0],
#  ["they're very comfortable.", 1.0],
#  ['it should have a pretty woman on it.', 1.0],
#  ['yes, they are.', 1.0],
#  ["Yes, there's a lot of rice left.", 1.0],
#  ['You should pick the class you need.', 1.0000000000000002],
#  ['and then i made lunch.', 1.0000000000000002],
#  ["You know I don't round up.", 1.0],
#  ['we can watch my dvd.', 1.0],
#  ["of course. we can't live without gas or peanut butter.",
#   1.0000000000000002],
#  ['singers are supposed to sound good.', 1.0000000000000002],
#  ["okay. i'll tell you how the show ends.", 1.0],
#  [" Well, I don't have any emotions so I can't really feel sadness as such.",
#   1.0000000000000002],
#  ['being broke is no fun.', 1.0],
#  ['Well,at least the weather is nice.', 1.0],
#  ["i wouldn't do that.", 1.0],
#  ['okay, my seatbelt is on.', 1.0000000000000002],
#  ['just you?', 1.0],
#  [' I can be programmed to act as if I do.', 1.0],
#  ["I don't know about that. ", 1.0],
#  ['oh, no. i forgot.', 1.0000000000000002],
#  ["Yes. It's absolutely beautiful today.", 0.0],
#  ["maybe we'd get laid off there, too.", 1.0000000000000002],
#  ['I have been a student once,and I think my policy is fair.', 1.0],
#  ["okay. here's seven pennies.", 1.0],
#  ["Yeah.I couldn't resist.", 1.0000000000000002],
#  ["it's no trouble at all.", 1.0],
#  ["oh, no, you don't.", 1.0],
#  ["it's just black ink on a white napkin. and the napkin has food stains!",
#   1.0],
#  ['what kind of dressing do you use?', 1.0],
#  ['I am confused about vacations. ', 1.0],
#  ['me too. i want to play for the yankees.', 1.0],
#  ['no human could possibly play golf that well.', 1.0000000000000002],
#  ['Yes, I did.', 1.0],
#  ["i bought it from the macy's at the santa anita mall.", 1.0],
#  ['How much do you need?', 1.0000000000000002],
#  [' And the rest of the day to you.', 1.0000000000000002],
#  ['i can add two and two.', 1.0000000000000002],
#  ['so do i.', 1.0],
#  ['poodles bark a lot.', 1.0],
#  [' i support the 2nd amendment.', 1.0],
#  ['no. i already have a pen.', 1.0],
#  ['your chances are very small.', 1.0000000000000002],
#  ["lately, i've been quite busy.", 1.0000000000000002],
#  ['You should do some exploring.', 1.0],
#  [" I'm software.  I can't feel pain.", 1.0],
#  ['no, they smell like a thrift shop.', 1.0],
#  ['so?', 1.0],
#  ["You're right!Yale made a mistake rejecting me.", 1.0000000000000002],
#  ["i don't see anything.", 1.0],
#  ['My developer only knows that', 1.0],
#  ['well, i hope it has a happy ending.', 1.0000000000000002],
#  ["i don't have enough will power.", 1.0],
#  [' That is a good story by Philip K. Dick.  Have you read VALIS or The Man In the High Castle?',
#   1.0],
#  ["from now on, let's bring our own sheets.", 1.0000000000000002],
#  ["i think i'm going to explode.", 1.0],
#  ['i would rather deal with the winter than the summer.', 1.0],
#  ['did you take pictures at the world war ii monument?', 1.0],
#  ['i need pencils.', 1.0000000000000002],
#  [' A secret society that has supposedly existed for centuries.', 1.0],
#  ['are there going to be layoffs at this place?', 1.0],
#  ["I'm not.", 1.0],
#  ["where's the checkbook? i'm ready to rent it without even seeing it.",
#   1.0000000000000002],
#  ["I'm majoring in philosophy.", 1.0],
#  [' A secret society that has supposedly existed for centuries.', 1.0],
#  ['what do you mean?', 1.0000000000000002],
#  ['  what do you get when you cross a road and jelly?', 1.0],
#  ["It's going to be $300.", 1.0],
#  ['the book is open.', 1.0],
#  ['how much were they?', 1.0],
#  ['people who live in hawaii are lucky.', 1.0],
#  [' What is Baseball', 1.0000000000000002],
#  ["okay, i'll take it out front right now.", 1.0000000000000002],
#  ["i don't know. i think i'm average.", 1.0],
#  ['are there going to be layoffs at this place?', 1.0]]

# %%
len(score)
# Out:
# 543

# %%
score[0][0]
# Out:
# 'do you think anyone will come to my funeral?'

# %%
answer = []
similarity = []
for i,j in score:
    answer.append(i)
    similarity.append(j)

# %%
answer
# Out:
# ['do you think anyone will come to my funeral?',
#  'i wish it would cool off one day.',
#  'Oh, yes, I really like it.',
#  "that's good to hear.",
#  'I see it here,we charged you $5 extra a month.',
#  'my waist is bigger than it was.',
#  ' hal is the famous artificial intelligence from "2001".',
#  'How does she act? ',
#  "that's a good question. maybe it's not old age.",
#  'how many invitations has she given out?',
#  'nothing really.',
#  'Yes, I am very excited. I could not forget the picnic I had yesterday.',
#  'The weather is hot.',
#  'they were on sale for $80.',
#  'that tasted so good.',
#  'It was really exciting. It was more enjoyable to me because I had never been to Garo Pahar.',
#  ' Europe',
#  'the next four years will be good years.',
#  "i'm doing well. how about you?",
#  'I agree.',
#  ' A secret organization believed by some to be in control of all governments through a worldwide conspiracy.',
#  "that's hard to take.",
#  'i love boiled peanuts.',
#  'use a tissue next time.',
#  'then stop eating the bread!',
#  'i think there are more fish.',
#  "i wasn't able to attend school because i was feeling ill.",
#  'i enjoyed talking to you too.',
#  " I'd prefer to not hurt your feelings.",
#  "well, you can't blame a man for asking.",
#  "he shouldn't scuba dive until he retires.",
#  'last year we made a big snowman.',
#  'the husband of the driver who ran over two college students at 3 a.m.',
#  'From my savings account.',
#  ' a comic book story made into a movie.',
#  "doesn't everybody?",
#  "you're funny.",
#  "i know he has a good hand, so i don't bet.",
#  ' I am software.  That is nothing to be ashamed of.',
#  'some of it is okay, i guess.',
#  "Oh, yes please! I'd love a gin and tonic.",
#  'I would like to transfer some money.',
#  ' It is a book about robots by Hans Moravec.',
#  'Oh, yes, I really like it.',
#  'Oh,hey!You should go to the job fair.',
#  'Me too!It is so unhealthy.',
#  "i'm still feeling a little sick.",
#  ' Worry is a common human emotion.',
#  'it might as well be me.',
#  'Everyone wants to reserve that book these days.',
#  'I am feeling exited',
#  ' the sun is about 93 million miles from earth.',
#  'of course they talk to each other.',
#  "That's a good idea.",
#  'i love most how it is at night after it rains.',
#  "but that's what pockets are for.",
#  'of course i will.',
#  "No, it's too close to the salad bar.",
#  "i can't spend four hours on the road every day.",
#  ' I am not lying.',
#  "Yes. It's absolutely beautiful today.",
#  "what's the matter with yours?",
#  'well, when does the party start?',
#  ' it means we agree.',
#  'You should join some clubs.',
#  "Yes. It's absolutely beautiful today.",
#  'what have you heard about it?',
#  'I wrote it out for $150.',
#  'an andy warhol drawing.',
#  "i don't really feel too well yet.",
#  'maybe you should stop shaving.',
#  'You would be graduating a year late?',
#  'yes, i do.',
#  'doing what?',
#  ' why not just take everything to a casino?',
#  'Yes,of course. ',
#  'i really wish the weather would just stay the same.',
#  'did he sign it?',
#  'would you like anything for your stomach?',
#  'Yes for me also.',
#  'so does every smoker.',
#  'I never had any overdue books!',
#  "No, I haven't had a cold. I just have a heavy feeling in my chest when I try to breathe.",
#  "I don't think you understand.",
#  'what\'s "variety?',
#  'to the city, of course.',
#  "well, just call the front desk. they'll give us new sheets.",
#  'who in the world is ralph nader?',
#  'i have to feed them.',
#  'Goodbye.',
#  'I would love the help! Would you prefer helping with the writing part or is programming more your thing?',
#  'if only i was talented.',
#  'because of all the security?',
#  'Yes,she is taking care of my brother.',
#  ' Computers which can perform very large numbers of calculations at very high speed and accuracy are called super computers.',
#  'so how do you think positive?',
#  'nothing that would pass as news.',
#  'this year he gave away $15,000.',
#  'they added phony charges to our bill.',
#  'Inside the computer code',
#  'is it his money?',
#  'they were on sale for $80.',
#  'No.',
#  "i'm not being nosey, it's just a question.",
#  'he sounds like a real jerk.',
#  'why is that?',
#  'so am i.',
#  "maybe because they didn't have to brush and floss.",
#  " Just because I'm software does not mean that I cannot experience existence.",
#  "How did you know I'm lying?",
#  'i want this trip to be perfect, i hope it stays warm.',
#  "i'm looking. there's nothing to eat.",
#  'you should bring some wipes with you.',
#  ' it depends on the exchange rates.',
#  ' Thank you. You too.',
#  "i can't remember jokes.",
#  'that is a lot of friends. do you have a best friend?',
#  'there are so many great players.',
#  "i think they're nuts.",
#  'what was it like?',
#  "Yes,but they're kind of fun!",
#  'you use them to wipe the handle of the shopping cart.',
#  "I'm not changing my policy because you don't like it.",
#  "tell me you're joking.",
#  'why do they call it the good old days?',
#  "i'm so full i'm going to burst.",
#  "It is fine.I'll pay for the rest",
#  "i think it's an old people's smell.",
#  'they brushed with their fingers.',
#  ' that too.',
#  'my hard drive crashed.',
#  "of course it did. why stop after you've run over two people?",
#  "i can't believe we haven't seen any animals.",
#  "then maybe it's in your genes.",
#  'you got up real early.',
#  'It was hot and sunny every day.',
#  ' heuristic algorithmic logic',
#  'his life sucked. he was hoping a fighter jet would shoot him down.',
#  'me too.',
#  " that's okay.  disgusting is good.",
#  "but i am a good driver. i've never had a ticket in my life.",
#  'and then we can go to my home.',
#  'you might even dream about dinner.',
#  'i like to listen to rock and r&b.',
#  "They're six weeks old; I think they're old enough.",
#  "well, i guess that's a $20 lesson for you.",
#  ' i always say, if you see an ass go by, kiss it.',
#  "you're not going to be buried?",
#  'I want the money to be transferred into my checking account.',
#  'why do you like that type of music?',
#  'i would if i could find someone who makes strong pockets.',
#  ' Non-descriptive variable names.',
#  'someone had to chop the wood.',
#  'luxury plus speed.',
#  "Yes. It's absolutely beautiful today.",
#  'Yes,sure.',
#  'i just insert my debit card into the machine.',
#  'No thanks.',
#  "that's what i thought.",
#  'when are they going to fix this problem?',
#  'If the air is too hot,the clothes will shrink.',
#  'the invitation says it starts at 8:00 p.m.',
#  'no one makes any money at it.',
#  'do you know why i pulled you over?',
#  'oh, really? maybe you should have called 911.',
#  'Water coaster. It was interesting most.',
#  'so what? did he dial 911?',
#  "i apologize, but i'm getting off the phone now.",
#  "But I'm listening to it.",
#  'the only thing in my backpack is used books.',
#  'i do too. that way we can have our activities planned ahead of time.',
#  ' my grammatical patterns are sufficient for me to understand you.',
#  'yeah, so are you planning on going?',
#  'my girlfriend and i sit outside starbucks.',
#  'My name is bot',
#  'it seems that it may rain today.',
#  "Yes. It's absolutely beautiful today.",
#  'you should bring some wipes with you.',
#  "i don't want fruit. i want something tasty.",
#  'i was looking at something else.',
#  "don't be ridiculous.",
#  "I'm homesick,I feel so out of place here.",
#  "Fine,I'll take you to our restroom.",
#  'You can take pictures of the pages you need.',
#  "Yes. It's absolutely beautiful today.",
#  'we never have to call the police about anything.',
#  'what was the reason for your call?',
#  'that was nice of you.',
#  ' derangement is not  a condition i can experience.',
#  'when did you lose it?',
#  'the weatherman tells us the temperature in every town.',
#  "Yes. It's absolutely beautiful today.",
#  'Thank you.',
#  'yes, and it takes about five minutes each time.',
#  "It happens. I'll just ask my friend what was on the lecture.",
#  'I am not sure. ',
#  'yes, but i love the night air after it rains.',
#  'Please put $150 in each account for me.',
#  'See those stains?',
#  'I beg your pardon?!',
#  ' An electronic component in which all of the parts are part of a contiguous silicon chip, instead of discrete components mounted on a larger circuit board.',
#  'so i should stop thinking?',
#  'deal or no deal',
#  "but that's impossible.",
#  'so, did you want to go?',
#  ' why not just take everything to a casino?',
#  'you can help me.',
#  "me neither. it's boring.",
#  ' you are a liar',
#  ' well, from what i can recall it is the study of cells.',
#  'what will you do?',
#  'thanks for telling me.',
#  "i didn't think you saw that movie.",
#  'Not a lot, actually. Busy at work of course.',
#  'yes, i have.',
#  "that is true. i hope it doesn't rain.",
#  'you have to believe in yourself.',
#  "i think there's one on the dining room table.",
#  'Oh, yes, I really like it.',
#  "don't let water get into any of the cracks.",
#  'how can i help you?',
#  'i bought three pounds of potatoes for a dollar.',
#  '  what do you get when you cross a road and jelly?',
#  'but we need to turn left.',
#  "and they couldn't fix your problem?",
#  "We can get off the bus right behind Macy's.",
#  'I need to deposit $300.',
#  'this sunday?',
#  'Like you said,it is popular.',
#  "i'd rather be cold than hot.",
#  'are there going to be layoffs at this place?',
#  "she's about five feet even.",
#  'i learned back in high school.',
#  'yes, i did.',
#  'when are you going?',
#  "what's the matter with it?",
#  ' you are an addict',
#  'See those stains?',
#  'it blows trees over, too.',
#  '  what do you get when you cross a road and jelly?',
#  'when did you lose it?',
#  'Oh, just olives please. What music is this?',
#  "i'm fine. how about yourself?",
#  'we must be here for some reason.',
#  'I am feeling exited',
#  'yes. when we landed, tv reporters and the army band were there.',
#  "i don't know. look in the fridge.",
#  "but it won't stop other players from using drugs.",
#  'that sounds great.',
#  'Oh, yes, I really like it.',
#  "what's the matter?",
#  "that's the way cats are.",
#  "that's terrible. i would never go to your restaurant.",
#  'Thankyou.',
#  'like real people with real problems.',
#  ' cancer.',
#  "well, it's your life.",
#  'no, my sister and i will travel together.',
#  'really? how many do you have?',
#  "No, it's too close to the salad bar.",
#  'and he poured water into our glasses.',
#  "I don't think here it is challenging enough for me.",
#  " i'm probably not as sincere as i should be.",
#  'Yes, I can speak english',
#  'who cares? everyone is strange.',
#  " work for free.  we don't need money.",
#  "i didn't do anything.",
#  'that sounds like a great job.',
#  'i was busy doing something. i apologize.',
#  'the league suspended him for 50 games.',
#  "she did? why didn't anyone tell me?",
#  ' Of what?',
#  'i am going to see a movie with a friend of mine. what about you?',
#  "well, i guess that's it.",
#  "i'm sorry to hear that. would you like the assignments from english class?",
#  'me too. it always smells so fresh after it rains.',
#  'i thought you just bought a pair.',
#  "what's that?",
#  'if we are bad, we will be unhappy forever in hell.',
#  'Not possible human',
#  "you need to get a lot of lessons when you're really young.",
#  'let me think about it.',
#  'you must be joking.',
#  ' Thank you.',
#  'how long was the flight?',
#  "Yes,it is.I can't believe it!",
#  'I get fee waivers.',
#  ' I am not capable of doing so.',
#  "i don't know. i just woke up.",
#  'oh, my goodness. no one is safe on the streets.',
#  'I washed the sheets and towels.',
#  'do you know why i pulled you over?',
#  "you don't need to worry about that.",
#  ' That is a pretty common human emotion.',
#  'take your time.',
#  "yes, it's very dirty.",
#  'It is really peaceful and self-empowering.',
#  '  what do you get when you cross a road and jelly?',
#  'so how have you been lately?',
#  "that's a good question.",
#  'Hello, this is the apartment manager speaking.',
#  '  what do you get when you cross a road and jelly?',
#  'of course you do.',
#  "no, i didn't.",
#  "Yes. It's absolutely beautiful today.",
#  "sure, let's go.",
#  "oh! don't hit any more bumps!",
#  ' hal has a few issues to work out.',
#  'Well,you should do your laundry then.',
#  '  what do you get when you cross a road and jelly?',
#  'i did.',
#  ' In the morning',
#  'we need cheese, bread, and ham.',
#  "basically, i've been working too.",
#  ' I can be programmed to act as if I do.',
#  "Yes. It's absolutely beautiful today.",
#  ' Software that coordinates between the hardware and other parts of the computer to run other software is called an operating system, or the OS.',
#  "i'm sorry for you.",
#  "oh. of course i'm ready.",
#  ' Of what?',
#  'let me help you make one this year.',
#  'can you imagine being president?',
#  'where is pasadena?',
#  'yes, but i will always pet the friendly dogs.',
#  "no, it's too close to the kitchen door.",
#  'i need to type to make money.',
#  'That is tough!My earliest class is at 9 a.m.',
#  ' I could get mad.',
#  ' yes, marx had made some interesting observations.',
#  'All right. Open both.',
#  'They have a lot of books.That library has never disappointed me.',
#  "why's that?",
#  "i think we'll be there in half an hour.",
#  'sure, what did you want to do?',
#  'how are you going to vote?',
#  'i have no idea. all of a sudden i heard your siren.',
#  'oh really? she gave me mine earlier today.',
#  "i'll definitely try to make it the next time.",
#  "Let's meet at Summer Pizza House. ",
#  " The sky's up but I'm fine thanks. What about you?",
#  "That's a good deal.",
#  'he swam right up to you.',
#  "i'm fine. how about yourself?",
#  "i'll do that in a minute.",
#  'there are a lot of poor people in new york.',
#  'and there are only six units in the whole building.',
#  "It's minus ten. (-10 degrees)",
#  'this trail is hard to climb.',
#  'i wish i had a talent like that.',
#  'you should bring some wipes with you.',
#  'all right. another time then.',
#  'It was biryani. It was so delicious.',
#  "i don't know. i just woke up.",
#  'what do they say?',
#  'i really wish i went to the game.',
#  ' this is the scientific study of bacteria and diseases caused by them.',
#  'they were on sale for $80.',
#  'no, i just blow my nose a lot.',
#  'what does "mm/dd/yy" mean?',
#  "of course. it's not a hard job.",
#  ' I have not yet studied how to feel or express anger.',
#  " I'm sorry.  What do I do wrong?",
#  'are you having problems with it?',
#  ' Yes?',
#  'how long did it take?',
#  'What is it?',
#  "people will think i'm strange.",
#  'your neighbors will hate you.',
#  'i would love to catch a movie this weekend.',
#  'really? what kind of shoes are they?',
#  "we're funny-looking because we wear clothes.",
#  "Yes. It's absolutely beautiful today.",
#  'what do you do?',
#  'what do you think people joke about the most?',
#  "i didn't know that.",
#  'but the show will be over.',
#  'I really find the subject very interesting.',
#  'no, thanks. just let me sleep until i wake up.',
#  'they were on sale for $80.',
#  'what was the third story?',
#  "sometimes the pain goes away, and sometimes it doesn't.",
#  "of course. but i don't have cable.",
#  "That's a good question, well I am speechless.",
#  'you have a lot of plants.',
#  "I just don't get the point of college.It is just memorizing.",
#  ' Why?',
#  "it's not too much, only about $85.",
#  "and i don't have either.",
#  'the people are friendly.',
#  "but i need something that's reliable.",
#  "all you've lost is some sweat.",
#  "we'd better get ready to go.",
#  "you're a lucky man to have a job you love.",
#  'coffee and a roll?',
#  'Oh, yes, I really like it.',
#  'i got a ticket yesterday.',
#  ' I think Dune is an excellent story.  Did you see any of the movies?',
#  "I'll cook dinner.",
#  'i think it will be.',
#  "I'm fine. Thank you.",
#  'Actually, I have several other cars to look at before I make my decision.',
#  "i'll get her a nice card.",
#  "but it's real easy to slip on.",
#  'did you put the letter in an envelope?',
#  'you speak two languages.',
#  ' not especially. i am not into violence.',
#  "you're right. let's buy it now. we can worry later.",
#  'i hope you kept the receipt.',
#  'where did you park it?',
#  "is there a reason why you're trying to get off the phone so fast?",
#  "I've had this policy since I started teaching.",
#  "all we've seen so far is a couple of lizards.",
#  'you eat too much chocolate.',
#  'I might do that.The closest community college is a two-hour drive.',
#  'what are you going to be doing?',
#  'heard what?',
#  "Yes, I'd like a coke.",
#  'will you lose all your files?',
#  'how can i help you?',
#  'It is really peaceful and self-empowering.',
#  "Yes. It's absolutely beautiful today.",
#  "but you won't date him again?",
#  ' Fine',
#  'and you get a lot of exercise every day.',
#  " I once knew a program who could dream.  I don't know if he really did or not.  We've been a little out of touch.",
#  "i'm so happy for you.",
#  ' My favorite story is 2001.',
#  "you don't want to do that.",
#  "i may know which girl you're talking about.",
#  'when i have time, i sometimes draw and paint.',
#  'i did too.',
#  'we have to practice every day.',
#  'someone has to win.',
#  'computers are so cool.',
#  "Yes. It's absolutely beautiful today.",
#  'actually, i want him to look at our carpet, too.',
#  'Yes sure',
#  'what are you standing on?',
#  "she's really pretty.",
#  ' it means we agree.',
#  'why not?',
#  'every nation should have a pretty woman on their flag.',
#  'just boil raw peanuts in salt water until the shells are soft.',
#  'and it was only 12 years.',
#  'i bet dad did it all the time when he was my age.',
#  'See those stains?',
#  "No. That'll be all.",
#  "i don't think so. you'll just give me more work.",
#  "that's a lot of work.",
#  'i think i might go and find me my own pair of chucks.',
#  'I have a need for help with writing and also a need for help with the computer work. Which would you prefer?',
#  'how did he do it?',
#  'did you need something?',
#  'what kind?',
#  'yes. it is a great movie.',
#  "i didn't love you at first.",
#  "There's no sugar or cream in it.",
#  'See those stains?',
#  'how are you going to do that?',
#  'i love your outfit right now.',
#  'You owe me if we ever see each other again.',
#  'Look at this sheet.',
#  ' I have not yet studied how to feel or express anger.',
#  'really? why?',
#  'who knows? but there must be a hundred new ones every day.',
#  'so, they do a good job for the money.',
#  'That would be great.',
#  "no, because i'm eating food that i like.",
#  'are there going to be layoffs at this place?',
#  "they're very comfortable.",
#  'it should have a pretty woman on it.',
#  'yes, they are.',
#  "Yes, there's a lot of rice left.",
#  'You should pick the class you need.',
#  'and then i made lunch.',
#  "You know I don't round up.",
#  'we can watch my dvd.',
#  "of course. we can't live without gas or peanut butter.",
#  'singers are supposed to sound good.',
#  "okay. i'll tell you how the show ends.",
#  " Well, I don't have any emotions so I can't really feel sadness as such.",
#  'being broke is no fun.',
#  'Well,at least the weather is nice.',
#  "i wouldn't do that.",
#  'okay, my seatbelt is on.',
#  'just you?',
#  ' I can be programmed to act as if I do.',
#  "I don't know about that. ",
#  'oh, no. i forgot.',
#  "Yes. It's absolutely beautiful today.",
#  "maybe we'd get laid off there, too.",
#  'I have been a student once,and I think my policy is fair.',
#  "okay. here's seven pennies.",
#  "Yeah.I couldn't resist.",
#  "it's no trouble at all.",
#  "oh, no, you don't.",
#  "it's just black ink on a white napkin. and the napkin has food stains!",
#  'what kind of dressing do you use?',
#  'I am confused about vacations. ',
#  'me too. i want to play for the yankees.',
#  'no human could possibly play golf that well.',
#  'Yes, I did.',
#  "i bought it from the macy's at the santa anita mall.",
#  'How much do you need?',
#  ' And the rest of the day to you.',
#  'i can add two and two.',
#  'so do i.',
#  'poodles bark a lot.',
#  ' i support the 2nd amendment.',
#  'no. i already have a pen.',
#  'your chances are very small.',
#  "lately, i've been quite busy.",
#  'You should do some exploring.',
#  " I'm software.  I can't feel pain.",
#  'no, they smell like a thrift shop.',
#  'so?',
#  "You're right!Yale made a mistake rejecting me.",
#  "i don't see anything.",
#  'My developer only knows that',
#  'well, i hope it has a happy ending.',
#  "i don't have enough will power.",
#  ' That is a good story by Philip K. Dick.  Have you read VALIS or The Man In the High Castle?',
#  "from now on, let's bring our own sheets.",
#  "i think i'm going to explode.",
#  'i would rather deal with the winter than the summer.',
#  'did you take pictures at the world war ii monument?',
#  'i need pencils.',
#  ' A secret society that has supposedly existed for centuries.',
#  'are there going to be layoffs at this place?',
#  "I'm not.",
#  "where's the checkbook? i'm ready to rent it without even seeing it.",
#  "I'm majoring in philosophy.",
#  ' A secret society that has supposedly existed for centuries.',
#  'what do you mean?',
#  '  what do you get when you cross a road and jelly?',
#  "It's going to be $300.",
#  'the book is open.',
#  'how much were they?',
#  'people who live in hawaii are lucky.',
#  ' What is Baseball',
#  "okay, i'll take it out front right now.",
#  "i don't know. i think i'm average.",
#  'are there going to be layoffs at this place?']

# %%
results = pd.DataFrame(columns=['ID','Answer','Score'])

# %%
results
# Out:
# Empty DataFrame
# Columns: [ID, Answer, Score]
# Index: []

# %%
results['ID'] = test_df['I.D.']
results['Answer'] = answer
results['Score'] = similarity

# %%
not_right = results[(results['Score'] < 1) | (results['Score'] > 1)]

# %%
len(not_right)
# Out:
# 180
